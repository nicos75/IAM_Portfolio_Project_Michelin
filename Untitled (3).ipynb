# %%
import random
import string

# Générer des prénoms et noms aléatoires
def generate_names(count):
    first_names = ["Alice", "Bob", "Charlie", "Diana", "Eve", "Frank", "Grace", "Hank", "Ivy", "Jack", "Karen", "Leo",
                   "Mona", "Nina", "Oscar", "Paul", "Quincy", "Rose", "Steve", "Tina", "Uma", "Victor", "Wendy", "Xander",
                   "Yara", "Zack"]
    last_names = ["Smith", "Johnson", "Brown", "Taylor", "Anderson", "Thomas", "Jackson", "White", "Harris", "Martin",
                  "Thompson", "Garcia", "Martinez", "Robinson", "Clark", "Rodriguez", "Lewis", "Lee", "Walker", "Hall",
                  "Allen", "Young", "King", "Wright", "Scott"]

    return random.choices(first_names, k=count), random.choices(last_names, k=count)

# Générer des mots de passe sécurisés
def generate_password(length=12):
    chars = string.ascii_letters + string.digits + "!@#$%^&*()"
    return ''.join(random.choice(chars) for _ in range(length))

# Générer noms d'utilisateur et mots de passe
def generate_users(count):
    first_names, last_names = generate_names(count)
    users = []

    for i in range(count):
        username = f"{first_names[i][0].lower()}{last_names[i].lower()}{random.randint(100, 999)}"
        password = generate_password()
        users.append({
            "First Name": first_names[i],
            "Last Name": last_names[i],
            "Username": username,
            "Password": password
        })

    return users

# Générer 100 utilisateurs
users = generate_users(100)

# Afficher les résultats
for user in users:
    print(f"First Name: {user['First Name']}, Last Name: {user['Last Name']}, Username: {user['Username']}, Password: {user['Password']}")
# Out:
# First Name: Jack, Last Name: King, Username: jking978, Password: e(pZaPY559W2
# First Name: Hank, Last Name: Clark, Username: hclark426, Password: Sy@PVIuT)GFs
# First Name: Grace, Last Name: Brown, Username: gbrown138, Password: KF01#zC6Kv#*
# First Name: Uma, Last Name: Rodriguez, Username: urodriguez893, Password: SNODgFePmgvz
# First Name: Eve, Last Name: Garcia, Username: egarcia277, Password: hfL^02O2iQ5G
# First Name: Paul, Last Name: Anderson, Username: panderson790, Password: &DPyqWa!jPs!
# First Name: Victor, Last Name: Clark, Username: vclark461, Password: Tf^^9W)5ba*i
# First Name: Alice, Last Name: Walker, Username: awalker826, Password: 14pVop&Iv7^5
# First Name: Tina, Last Name: Rodriguez, Username: trodriguez480, Password: puCA6B2no1Ul
# First Name: Victor, Last Name: Taylor, Username: vtaylor558, Password: X*EdtZTVEcOz
# First Name: Hank, Last Name: Robinson, Username: hrobinson940, Password: 7$(EVrhSna)J
# ...

# %%
from faker import Faker

# Create a Faker instance
fake = Faker()

# Generate 100 users
users = [{"first_name": fake.first_name(), "last_name": fake.last_name()} for _ in range(100)]

# Display the generated users
for user in users:
    print(user)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from faker import Faker
#       3 # Create a Faker instance
#       4 fake = Faker()
#
# ModuleNotFoundError: No module named 'faker'

# %%
pip install faker
# Out:
#   Input In [6]
#     pip install faker
#         ^
# SyntaxError: invalid syntax

# %%
pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#      |████████████████████████████████| 1.9 MB 25.0 MB/s eta 0:00:01
# ...
#   WARNING: The script faker is installed in '/home/081136e8-b48f-4f10-9d9d-8084412f489b/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
# Create a Faker instance
fake = Faker()

# Generate 100 users
users = [{"first_name": fake.first_name(), "last_name": fake.last_name()} for _ in range(100)]

# Display the generated users
for user in users:
    print(user)
# Out:
# {'first_name': 'Denise', 'last_name': 'Snyder'}
# {'first_name': 'Kelly', 'last_name': 'Arias'}
# {'first_name': 'Sarah', 'last_name': 'Dickerson'}
# {'first_name': 'Jeff', 'last_name': 'Baldwin'}
# {'first_name': 'Kelli', 'last_name': 'Lynn'}
# {'first_name': 'Alexandria', 'last_name': 'Gilbert'}
# {'first_name': 'Kelly', 'last_name': 'Lewis'}
# {'first_name': 'Shelley', 'last_name': 'Ortega'}
# {'first_name': 'William', 'last_name': 'Cunningham'}
# {'first_name': 'Sara', 'last_name': 'Li'}
# {'first_name': 'Krista', 'last_name': 'Bray'}
# {'first_name': 'Joshua', 'last_name': 'Hooper'}
# {'first_name': 'Melissa', 'last_name': 'Rivera'}
# {'first_name': 'Denise', 'last_name': 'Garcia'}
# {'first_name': 'Lori', 'last_name': 'Brooks'}
# {'first_name': 'Patrick', 'last_name': 'Mendoza'}
# {'first_name': 'Kathy', 'last_name': 'Warren'}
# {'first_name': 'Diane', 'last_name': 'Miller'}
# {'first_name': 'Theresa', 'last_name': 'Bailey'}
# ...

# %%
import random
import string
import csv
import pandas as pd
from faker import Faker

# Create a Faker instance
fake = Faker()

# Generate 100 users
users = [{"first_name": fake.first_name(), "last_name": fake.last_name()} for _ in range(100)]

# Generate secure passwords
def generate_password(length=12):
    chars = string.ascii_letters + string.digits + "!@#$%^&*()"
    return ''.join(random.choice(chars) for _ in range(length))

# Generate usernames and passwords
def generate_users(count):
    first_names = [fake.first_name() for _ in range(count)]  # Generate first names
    last_names = [fake.last_name() for _ in range(count)]    # Generate last names
    users = []

    for i in range(count):
        username = f"{first_names[i][0].lower()}{last_names[i].lower()}{random.randint(100, 999)}"
        password = generate_password()
        users.append({
            "First Name": first_names[i],
            "Last Name": last_names[i],
            "Username": username,
            "Password": password
        })

    return users

# Define the function to generate a CSV file
def generate_csv(users):
    with open('users.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["First Name", "Last Name", "Username", "Password"])
        writer.writeheader()  # Write the header
        writer.writerows(users)  # Write the user data

# Generate users and store them in a new list
generated_users = generate_users(100)

# Call the function to generate the CSV file
generate_csv(generated_users)

# Export to Excel with a new file name
df = pd.DataFrame(generated_users)
df.to_excel('user_data.xlsx', index=False)  # Changed file name here
print("Excel file generated successfully.")
# Out:
# Excel file generated successfully.

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /home/081136e8-b48f-4f10-9d9d-8084412f489b

# %% [markdown]
# # User
# I want to change the export file name for this excel file

# %% [markdown]
# # Assistant
# The error you're encountering is due to the specified directory `'elab/Desktop'` not existing on your system. To fix this, you can either create the directory or change the export path to a valid directory that exists.
#
# If you want to change the export file name for the Excel file, you can simply modify the string in the `to_excel` method.
#
# Would you like me to provide the corrected code with a new export file name and a valid path?

# %% [markdown]
# # User
# yes

# %% [markdown]
# # Assistant
# Here's the corrected code with a new export file name and a valid path. I will change the export file name to `user_data.xlsx` and use the current working directory for saving the file:

# %%
import random
import string
import csv
import pandas as pd
from faker import Faker

fake = Faker()

# Function to generate a random password
def generate_password(length=8):
    chars = string.ascii_letters + string.digits + "!@#$%^&*()"
    return ''.join(random.choice(chars) for _ in range(length))

# Generate usernames and passwords
def generate_users(count):
    first_names = [fake.first_name() for _ in range(count)]  # Generate first names
    last_names = [fake.last_name() for _ in range(count)]    # Generate last names
    users = []

    for i in range(count):
        username = f"{first_names[i][0].lower()}{last_names[i].lower()}{random.randint(100, 999)}"
        password = generate_password()
        users.append({
            "First Name": first_names[i],
            "Last Name": last_names[i],
            "Username": username,
            "Password": password
        })

    return users

# Define the function to generate a CSV file
def generate_csv(users):
    with open('users.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["First Name", "Last Name", "Username", "Password"])
        writer.writeheader()  # Write the header
        writer.writerows(users)  # Write the user data

# Generate users and store them in a new list
generated_users = generate_users(100)

# Call the function to generate the CSV file
generate_csv(generated_users)

# Export to Excel with a new file name
df = pd.DataFrame(generated_users)
df.to_excel('user_data.xlsx', index=False)  # Changed file name here
print("Excel file generated successfully.")
# Out:
# Excel file generated successfully.

# %% [markdown]
# ### Changes made:
# - The export file name for the Excel file has been changed to `user_data.xlsx`.
# - The path for saving the file has been simplified to the current working directory, which should exist.
#
# Make sure to run this code in a directory where you have write permissions.

# %% [markdown]
# # User
# still can't find the file. I want to save to in a specific path. Correct the code to enable me to do that

# %% [markdown]
# # Assistant
# To save the Excel file to a specific path, you need to ensure that the directory exists before trying to save the file there. If the directory does not exist, you can create it using Python's `os` module.
#
# Let's say you want to save the file to a specific path like `C:/Users/YourUsername/Desktop/`. You can replace `YourUsername` with your actual username or any other valid path on your system.
#
# Here's the corrected code that ensures the directory exists and saves the Excel file to a specified path:

# %%
import random
import string
import csv
import pandas as pd
import os
from faker import Faker

fake = Faker()

# Function to generate a random password
def generate_password(length=8):
    chars = string.ascii_letters + string.digits + "!@#$%^&*()"
    return ''.join(random.choice(chars) for _ in range(length))

# Function to assign age above 25
def assign_age():
    return random.randint(26, 60)  # Age between 26 and 60

# Function to assign a random job title
def assign_function():
    job_titles = ['Marketing Associate', 'VP', 'Secretary', 'Supply Chain analyst', 'IAM consultant', 'Finance auditor', 'Finance analyst', 'Marketing VP', 'DevOps engineer', 'data scientist', 'data analyst', 'Machine Learning Engineer', 'Product Analyst', 'Business Intelligence Analyst', 'Deep Learning Specialist', 'Data Marketer', 'Data Governance Specialist', 'Production manager', 'Machine operator']
    return random.choice(job_titles)

# Function to create an email address
def generate_email(first_name, last_name):
    first_initial = first_name[0].lower()  # Get the first letter of the first name
    last_name_lower = last_name.lower()     # Convert last name to lowercase
    email = f"{first_initial}.{last_name_lower}@michelin.fr"  # Construct the email
    return email

# Generate usernames and passwords
def generate_users(count):
    first_names = [fake.first_name() for _ in range(count)]  # Generate first names
    last_names = [fake.last_name() for _ in range(count)]    # Generate last names
    users = []

    for i in range(count):
        username = f"{first_names[i][0].lower()}{last_names[i].lower()}{random.randint(100, 999)}"
        password = generate_password()
        email = generate_email(first_names[i], last_names[i])
        age = assign_age()  # Assign age
        job_title = assign_function()  # Assign job title
        users.append({
            "First Name": first_names[i],
            "Last Name": last_names[i],
            "Username": username,
            "Password": password,
            "Email": email,
            "Age": age,  # Add age to user data
            "Job Title": job_title  # Add job title to user data
        })

    return users

# Define the function to generate a CSV file
def generate_csv(users):
    with open('users.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["First Name", "Last Name", "Username", "Password", "Email", "Age", "Job Title"])
        writer.writeheader()  # Write the header
        writer.writerows(users)  # Write the user data

# Generate users and store them in a new list
generated_users = generate_users(100)

# Call the function to generate the CSV file
generate_csv(generated_users)

# Specify the path where you want to save the Excel file
output_directory = os.path.expanduser('~/Downloads/')  # Changed to user's Downloads directory
output_file = os.path.join(output_directory, 'user_data.xlsx')

# Ensure the directory exists
os.makedirs(output_directory, exist_ok=True)

# Export to Excel with the specified file name and path
df = pd.DataFrame(generated_users)
df.to_excel(output_file, index=False)  # Save to the specified path
print(f"Excel file will be saved to: {output_file}")
# Out:
# Excel file will be saved to: /home/081136e8-b48f-4f10-9d9d-8084412f489b/Downloads/user_data.xlsx

# %% [markdown]
# In this corrected version, the `print` statement is aligned properly with the `import` statement, ensuring there are no unexpected indents.

# %% [markdown]
# # Assistant
# The error occurs because the variable `email` is being used in the `generate_users` function without being defined within that function. Specifically, the line where `email` is included in the user dictionary is problematic because `email` is not assigned a value in the scope of `generate_users`.
#
# To fix this, you need to generate the email address for each user inside the loop where you create the user data. You can do this by calling a function that constructs the email based on the first initial and last name.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# The error occurs because the variable `email` is being used in the `generate_users` function without being defined within that function. Specifically, the line where `email` is included in the user dictionary is problematic because `email` is not assigned a value in the scope of `generate_users`.
#
# To fix this, you need to generate the email address for each user inside the loop where you create the user data. You can do this by calling a function that constructs the email based on the first initial and last name.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# When you run this code in your Jupyter Notebook, it will display the current working directory. You can then use that path to locate your files on your computer. Let me know if you need any further assistance!
